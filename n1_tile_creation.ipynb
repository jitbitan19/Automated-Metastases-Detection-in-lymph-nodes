# %%
import os
import numpy as np
import h5py
from datetime import datetime
from skimage.filters import threshold_otsu
import matplotlib.pyplot as plt
from tqdm import tqdm
from skimage.filters import threshold_otsu

from preprocessing.datamodel import SlideManager
from preprocessing.processing import (
    split_negative_slide,
    split_positive_slide,
    rgb2gray,
)

# %%
t1 = datetime.now()

# %%
CAM_BASE_DIR = "/storage/jitbitan/"
CAM16_DIR = CAM_BASE_DIR + "Camelyon16/"
GENERATED_DATA = CAM_BASE_DIR + "outputs/cam16_tiles/"

# %%
sldmgr = SlideManager(cam16_dir=CAM16_DIR)
lvl = 3
tile_size = 256

# lvl = 0
# tile_size = 312

# %%
poi_normal = 0.2
poi_tumor = 0.6

overlap_normal = 0
overlap_tumor = tile_size // 2

# MAX_TILES = 1000

# %%
t2 = datetime.now()

# %%
neg_wsi = 0

for slide in sldmgr.negative_slides:
    arr = np.array(slide.get_full_slide(level=lvl))
    arr_gray = rgb2gray(arr)
    thr = threshold_otsu(arr_gray)

    tile_iter = split_negative_slide(
        slide,
        level=lvl,
        otsu_threshold=thr,
        tile_size=tile_size,
        overlap=overlap_normal,
        poi_threshold=poi_normal,
    )

    tile_count = 0
    all_tiles = []
    for tile, bounds in tile_iter:
        all_tiles.append(tile)
        tile_count += 1

    print(f"Negative WSI {neg_wsi+1}: {slide.name}\tTile Count: {tile_count}")
    neg_wsi += 1

    if tile_count == 0:
        continue

    tiles_data = np.stack(all_tiles)

    filename = "{}{}_tile{}_poiNormal{}_poiTumor{}_level{}.hdf5".format(
        GENERATED_DATA, slide.name, tile_size, poi_normal, poi_tumor, lvl
    )
    with h5py.File(filename, "w") as f:
        f.create_dataset(name=slide.name, data=tiles_data)
# Out:
# Negative WSI 1: normal_001	Tile Count: 185
# Negative WSI 2: normal_002	Tile Count: 324
# Negative WSI 3: normal_003	Tile Count: 398
# Negative WSI 4: normal_004	Tile Count: 111
# Negative WSI 5: normal_005	Tile Count: 256
# Negative WSI 6: normal_006	Tile Count: 86
# Negative WSI 7: normal_007	Tile Count: 320
# Negative WSI 8: normal_008	Tile Count: 164
# Negative WSI 9: normal_009	Tile Count: 469
# Negative WSI 10: normal_010	Tile Count: 201
# Negative WSI 11: normal_011	Tile Count: 888
# Negative WSI 12: normal_012	Tile Count: 232
# Negative WSI 13: normal_013	Tile Count: 145
# Negative WSI 14: normal_014	Tile Count: 221
# Negative WSI 15: normal_015	Tile Count: 421
# Negative WSI 16: normal_016	Tile Count: 77
# Negative WSI 17: normal_017	Tile Count: 42
# Negative WSI 18: normal_018	Tile Count: 234
# Negative WSI 19: normal_019	Tile Count: 23
# Negative WSI 20: normal_020	Tile Count: 68
# Negative WSI 21: normal_021	Tile Count: 37
# Negative WSI 22: normal_022	Tile Count: 501
# Negative WSI 23: normal_023	Tile Count: 127
# Negative WSI 24: normal_024	Tile Count: 996
# Negative WSI 25: normal_025	Tile Count: 647
# Negative WSI 26: normal_026	Tile Count: 539
# Negative WSI 27: normal_027	Tile Count: 54
# Negative WSI 28: normal_028	Tile Count: 370
# Negative WSI 29: normal_029	Tile Count: 231
# Negative WSI 30: normal_030	Tile Count: 324
# Negative WSI 31: normal_031	Tile Count: 676
# Negative WSI 32: normal_032	Tile Count: 562
# Negative WSI 33: normal_033	Tile Count: 642
# Negative WSI 34: normal_034	Tile Count: 1131
# Negative WSI 35: normal_035	Tile Count: 268
# Negative WSI 36: normal_036	Tile Count: 394
# Negative WSI 37: normal_037	Tile Count: 462
# Negative WSI 38: normal_038	Tile Count: 100
# Negative WSI 39: normal_039	Tile Count: 625
# Negative WSI 40: normal_040	Tile Count: 1161
# Negative WSI 41: normal_041	Tile Count: 524
# Negative WSI 42: normal_042	Tile Count: 13
# Negative WSI 43: normal_043	Tile Count: 142
# Negative WSI 44: normal_044	Tile Count: 521
# Negative WSI 45: normal_045	Tile Count: 238
# Negative WSI 46: normal_046	Tile Count: 186
# Negative WSI 47: normal_047	Tile Count: 455
# Negative WSI 48: normal_048	Tile Count: 199
# Negative WSI 49: normal_049	Tile Count: 258
# Negative WSI 50: normal_050	Tile Count: 776
# Negative WSI 51: normal_051	Tile Count: 363
# Negative WSI 52: normal_052	Tile Count: 904
# Negative WSI 53: normal_053	Tile Count: 900
# Negative WSI 54: normal_054	Tile Count: 124
# Negative WSI 55: normal_055	Tile Count: 404
# Negative WSI 56: normal_056	Tile Count: 441
# Negative WSI 57: normal_057	Tile Count: 367
# Negative WSI 58: normal_058	Tile Count: 404
# Negative WSI 59: normal_059	Tile Count: 254
# Negative WSI 60: normal_060	Tile Count: 101
# Negative WSI 61: normal_061	Tile Count: 975
# Negative WSI 62: normal_062	Tile Count: 215
# Negative WSI 63: normal_063	Tile Count: 418
# Negative WSI 64: normal_064	Tile Count: 1385
# Negative WSI 65: normal_065	Tile Count: 392
# Negative WSI 66: normal_066	Tile Count: 1695
# Negative WSI 67: normal_067	Tile Count: 1134
# Negative WSI 68: normal_068	Tile Count: 894
# Negative WSI 69: normal_069	Tile Count: 597
# Negative WSI 70: normal_070	Tile Count: 1069
# Negative WSI 71: normal_071	Tile Count: 476
# Negative WSI 72: normal_072	Tile Count: 834
# Negative WSI 73: normal_073	Tile Count: 575
# Negative WSI 74: normal_074	Tile Count: 766
# Negative WSI 75: normal_075	Tile Count: 643
# Negative WSI 76: normal_076	Tile Count: 1632
# Negative WSI 77: normal_077	Tile Count: 490
# Negative WSI 78: normal_078	Tile Count: 419
# Negative WSI 79: normal_079	Tile Count: 1001
# Negative WSI 80: normal_080	Tile Count: 1282
# Negative WSI 81: normal_081	Tile Count: 1009
# Negative WSI 82: normal_082	Tile Count: 811
# Negative WSI 83: normal_083	Tile Count: 296
# Negative WSI 84: normal_084	Tile Count: 218
# Negative WSI 85: normal_085	Tile Count: 377
# Negative WSI 86: normal_086	Tile Count: 695
# Negative WSI 87: normal_087	Tile Count: 948
# Negative WSI 88: normal_088	Tile Count: 947
# Negative WSI 89: normal_089	Tile Count: 1297
# Negative WSI 90: normal_090	Tile Count: 914
# Negative WSI 91: normal_091	Tile Count: 1691
# Negative WSI 92: normal_092	Tile Count: 601
# Negative WSI 93: normal_093	Tile Count: 567
# Negative WSI 94: normal_094	Tile Count: 737
# Negative WSI 95: normal_095	Tile Count: 992
# Negative WSI 96: normal_096	Tile Count: 786
# Negative WSI 97: normal_097	Tile Count: 937
# Negative WSI 98: normal_098	Tile Count: 266
# Negative WSI 99: normal_099	Tile Count: 1026
# Negative WSI 100: normal_100	Tile Count: 563
# Negative WSI 101: normal_101	Tile Count: 808
# Negative WSI 102: normal_102	Tile Count: 900
# Negative WSI 103: normal_103	Tile Count: 716
# Negative WSI 104: normal_104	Tile Count: 1348
# Negative WSI 105: normal_105	Tile Count: 753
# Negative WSI 106: normal_106	Tile Count: 1051
# Negative WSI 107: normal_107	Tile Count: 762
# Negative WSI 108: normal_108	Tile Count: 133
# Negative WSI 109: normal_109	Tile Count: 956
# Negative WSI 110: normal_110	Tile Count: 985
# Negative WSI 111: normal_111	Tile Count: 1961
# Negative WSI 112: normal_112	Tile Count: 1266
# Negative WSI 113: normal_113	Tile Count: 1085
# Negative WSI 114: normal_114	Tile Count: 1746
# Negative WSI 115: normal_115	Tile Count: 977
# Negative WSI 116: normal_116	Tile Count: 561
# Negative WSI 117: normal_117	Tile Count: 718
# Negative WSI 118: normal_118	Tile Count: 856
# Negative WSI 119: normal_119	Tile Count: 946
# Negative WSI 120: normal_120	Tile Count: 1328
# Negative WSI 121: normal_121	Tile Count: 1287
# Negative WSI 122: normal_122	Tile Count: 1244
# Negative WSI 123: normal_123	Tile Count: 955
# Negative WSI 124: normal_124	Tile Count: 1097
# Negative WSI 125: normal_125	Tile Count: 1772
# Negative WSI 126: normal_126	Tile Count: 924
# Negative WSI 127: normal_127	Tile Count: 1367
# Negative WSI 128: normal_128	Tile Count: 603
# Negative WSI 129: normal_129	Tile Count: 1683
# Negative WSI 130: normal_130	Tile Count: 975
# Negative WSI 131: normal_131	Tile Count: 1249
# Negative WSI 132: normal_132	Tile Count: 1138
# Negative WSI 133: normal_133	Tile Count: 1022
# Negative WSI 134: normal_134	Tile Count: 501
# Negative WSI 135: normal_135	Tile Count: 939
# Negative WSI 136: normal_136	Tile Count: 1003
# Negative WSI 137: normal_137	Tile Count: 1476
# Negative WSI 138: normal_138	Tile Count: 1602
# Negative WSI 139: normal_139	Tile Count: 1583
# Negative WSI 140: normal_140	Tile Count: 1253
# Negative WSI 141: normal_141	Tile Count: 559
# Negative WSI 142: normal_142	Tile Count: 1247
# Negative WSI 143: normal_143	Tile Count: 972
# Negative WSI 144: normal_144	Tile Count: 411
# Negative WSI 145: normal_145	Tile Count: 1546
# Negative WSI 146: normal_146	Tile Count: 887
# Negative WSI 147: normal_147	Tile Count: 1256
# Negative WSI 148: normal_148	Tile Count: 591
# Negative WSI 149: normal_149	Tile Count: 1519
# Negative WSI 150: normal_150	Tile Count: 335
# Negative WSI 151: normal_151	Tile Count: 838
# Negative WSI 152: normal_152	Tile Count: 843
# Negative WSI 153: normal_153	Tile Count: 547
# Negative WSI 154: normal_154	Tile Count: 975
# Negative WSI 155: normal_155	Tile Count: 478
# Negative WSI 156: normal_156	Tile Count: 677
# Negative WSI 157: normal_157	Tile Count: 877
# Negative WSI 158: normal_158	Tile Count: 976
# Negative WSI 159: normal_159	Tile Count: 1133
# Negative WSI 160: normal_160	Tile Count: 1095

# %%
t3 = datetime.now()

# %%
pos_wsi = 0

for slide in sldmgr.annotated_slides:
    tile_iter = split_positive_slide(
        slide,
        level=lvl,
        tile_size=tile_size,
        overlap=overlap_tumor,
        poi_threshold=poi_tumor,
    )

    tile_count = 0
    all_tiles = []
    for tile, bounds in tile_iter:
        all_tiles.append(tile)
        tile_count += 1

    print(f"Annotated WSI {pos_wsi+1}: {slide.name}\tTile Count: {tile_count}")
    pos_wsi += 1

    if tile_count == 0:
        continue

    tiles_data = np.stack(all_tiles)

    filename = "{}{}_tile{}_poiNormal{}_poiTumor{}_level{}.hdf5".format(
        GENERATED_DATA, slide.name, tile_size, poi_normal, poi_tumor, lvl
    )
    with h5py.File(filename, "w") as f:
        f.create_dataset(name=slide.name, data=tiles_data)
# Out:
# Annotated WSI 1: tumor_089	Tile Count: 1586
# Annotated WSI 2: tumor_090	Tile Count: 215
# Annotated WSI 3: tumor_091	Tile Count: 36
# Annotated WSI 4: tumor_092	Tile Count: 13
# Annotated WSI 5: tumor_093	Tile Count: 0
# Annotated WSI 6: tumor_094	Tile Count: 56
# Annotated WSI 7: tumor_095	Tile Count: 838
# Annotated WSI 8: tumor_096	Tile Count: 3
# Annotated WSI 9: tumor_097	Tile Count: 0
# Annotated WSI 10: tumor_098	Tile Count: 0
# Annotated WSI 11: tumor_099	Tile Count: 5
# Annotated WSI 12: tumor_100	Tile Count: 2
# Annotated WSI 13: tumor_101	Tile Count: 160
# Annotated WSI 14: tumor_102	Tile Count: 252
# Annotated WSI 15: tumor_103	Tile Count: 0
# Annotated WSI 16: tumor_104	Tile Count: 81
# Annotated WSI 17: tumor_105	Tile Count: 54
# Annotated WSI 18: tumor_106	Tile Count: 30
# Annotated WSI 19: tumor_107	Tile Count: 4
# Annotated WSI 20: tumor_108	Tile Count: 49
# Annotated WSI 21: tumor_109	Tile Count: 92
# Annotated WSI 22: tumor_110	Tile Count: 1000

# %%
t4 = datetime.now()

# %%
all_wsi = "{}all_wsi_tile{}_poiNormal{}_poiTumor{}_level{}.hdf5".format(
    GENERATED_DATA,
    tile_size,
    poi_normal,
    poi_tumor,
    lvl,
)
all_files = os.listdir(GENERATED_DATA)
all_files.sort()

with h5py.File(all_wsi, 'w') as f:
    for file in all_files:
        filename = GENERATED_DATA + file
        with h5py.File(filename, "r") as g:
            key = file[:10] if file.startswith("n") else file[:9]
            f.create_dataset(name=key, data=g[key][:])

# %%
t5 = datetime.now()

# %%
print(f"Processing Negative WSIs:\t{(t3-t2).seconds} seconds")
print(f"Processed Positive WSIs:\t{(t4 - t3).seconds} seconds")
print(f"Merged all WSIs:\t\t{(t5-t4).seconds} seconds")
print(f"Total Execution time:\t\t{(t5-t1).seconds} seconds")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(f"Processing Negative WSIs:\t{(t3-t2).seconds} seconds")
#       2 print(f"Processed Positive WSIs:\t{(t4 - t3).seconds} seconds")
#       3 print(f"Merged all WSIs:\t\t{(t5-t4).seconds} seconds")
#
# NameError: name 't3' is not defined
